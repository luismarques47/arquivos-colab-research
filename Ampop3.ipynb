# %% [markdown]
# <a href="https://colab.research.google.com/github/luismarques47/arquivos-colab-research/blob/master/Ampop3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício
# Determine ***Vo*** nos circuitos abaixo.

# %% [markdown]
# ![Captura de Tela 2021-06-28 às 18.34.28.png](data:image/png;base64,...)

# %%
import sympy as sp
v0 = sp.symbols('v0')
eq1 = sp.Eq(-4+0.001*2000+v0,0)
sp.solve(eq1,v0)
# Out:
# [2.00000000000000]

# %% [markdown]
# ![Captura de Tela 2021-06-28 às 18.40.26.png](data:image/png;base64,...)

# %%
eq1 = sp.Eq(-3+1+v0,0)
sp.solve(eq1,v0)
# Out:
# [2]
