# %% [markdown]
# <a href="https://colab.research.google.com/github/luismarques47/arquivos-colab-research/blob/master/circuitonorton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Teoremas de rede**

# %% [markdown]
# **Exercício: Determine o circuito Norton equivalente**

# %% [markdown]
# # ![Captura de Tela 2021-06-07 às 15.58.20.png](data:image/png;base64,...)

# %%
import sympy as sp
sp.init_printing()

# %%
i1 = sp.Symbol('i1')
f = sp.Eq(-120+20*i1+40*(i1+2)+12*i1, 0)
f
z = sp.solve(f,i1)
z
# Out:
# [5/9]

# %%
Vth = 12*(5/9)
Vth
# Out:
# 6.666666666666667

# %%
Req = (60*12)/(60+12)
Req
# Out:
# 10.0

# %%
In = Vth/Req
In
# Out:
# 0.6666666666666667
