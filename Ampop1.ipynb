# %% [markdown]
# <a href="https://colab.research.google.com/github/luismarques47/arquivos-colab-research/blob/master/Ampop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício
# Determine ***Vo*** no circuito abaixo.

# %% [markdown]
#  ![Captura de Tela 2021-06-23 às 15.28.29.png](data:image/png;base64,...)

# %%
import sympy as sp
v0 = sp.symbols('v0')
eq1 = sp.Eq(-1/2000-v0/10000,0)


sp.solve(eq1,v0)
# Out:
# [-5.00000000000000]
